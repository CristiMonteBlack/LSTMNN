# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import matplotlib.ticker as ticker
import seaborn as sns
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.impute import KNNImputer

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, GRU, LSTM, Embedding
from tensorflow.keras.optimizers import RMSprop

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display

# %% [markdown]
# # Function definition

# %%
#Funcion para ver la cantidad de valores nulos por columna
def count_null_incol(df,col):
    null_values = df[col].isnull().sum()
    print(f"Total null values in column {col}: {null_values}")
    return null_values

# %%
 def plot_loss(history):
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['loss'], label='Training loss')
    plt.plot(history.history['val_loss'], label='Validation loss')
    plt.title('Model loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %%
def multivariate_data(dataset
                      , target
                      , start_index # tipicaly 0 for train and "train_end_index" for test
                      , end_index # tipicaly "none" for test
                      , history_size # past observations to be considered 
                      , target_size # future observations associated to history
                      , step # gap data (explanation below)
                      , single_step=False): # whether to predict a single or multiple points
    data = []
    labels = []

    start_index = start_index + history_size
    if end_index is None:
        end_index = len(dataset) - target_size

    for i in range(start_index, end_index):
        indices = range(i-history_size, i, step)
        data.append(dataset[indices])

        if single_step:
            # label = a data point
            labels.append(target[i+target_size])
        else:
            # label = a sequence
            labels.append(target[i:i+target_size])

    return np.array(data), np.array(labels)

# %%
#This function is used to merge the information of the weather with the data of the buildings   
def merge_weather(data, df_weather):
    df = data.merge(df_weather , left_index=True, right_index=True, how='left') 
    return df

def f_scaler(df):
    scalers = {}
    df_scaled = pd.DataFrame()
    for column in df.columns:
        scaler = MinMaxScaler()
        column_scaled = scaler.fit_transform(df[[column]])
        df_scaled[column] = column_scaled.flatten()
        scalers[column] = scaler
        
    return scalers, df_scaled



def plot_loss(history):
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['loss'], label='Training loss')
    plt.plot(history.history['val_loss'], label='Validation loss')
    plt.title('Model loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
def plot_predictions(y_test, y_pred, zoom_in=False, zoom_start=None, zoom_end=None):
    plt.figure(figsize=(10, 6))
    plt.plot(y_test, label='Actual')
    plt.plot(y_pred, label='Predicted')
    plt.title('Electricity Demand Prediction')
    plt.xlabel('Time (hours)')
    plt.ylabel('Electricity Demand (MW)')
    plt.legend()
    
    if zoom_in:
        plt.xlim(zoom_start, zoom_end)
    
    plt.show()

# %%
# The function calculates the representativity of outliers in a given column of a dataset Outliers are data points that significantly deviate 
# from the majority of the data. The representativity of outliers is a measure of how much these extreme values contribute to the overall 
# dataset.

def calculate_outlier_representativity(column):
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR = Q3 - Q1

    lower_limit = Q1 - 1.5 * IQR
    upper_limit = Q3 + 1.5 * IQR

    outliers_count = len(column[(column < lower_limit) | (column > upper_limit)])

    outliers_representativity = outliers_count / len(column) * 100

    return outliers_representativity

# %%
# Generate a line plot for the variable of interest

def plotsb(data, var):
    # Create subplots for scatter plot and box plot
    fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(20, 8))
    fig.subplots_adjust(hspace=1.5)
    
    # Scatter plot
    ax1.scatter(data[var], data['electricity'])
    ax1.set_xlabel(var)
    ax1.set_ylabel('Energy Consumption')
    ax1.set_title('Scatter Plot: Energy Consumption vs {}'.format(var))

    # Box plot
    ax2.boxplot(data[var].dropna())
    ax2.set_ylabel('Electricity')
    ax2.set_title('Box Plot: {}'.format(var))

    # Display the subplots
    plt.show()

# %%
 def plot_loss(history):
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['loss'], label='Training loss')
    plt.plot(history.history['val_loss'], label='Validation loss')
    plt.title('Model loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %% [markdown]
# # Create Dataset

# %% [markdown]
# ## Weather data

# %%
df_weather = pd.read_csv('weather.csv')

df_weather_bobcat = df_weather[df_weather['site_id'] == 'Bobcat']

df_weather_bobcat.set_index('timestamp', inplace=True, drop=True)

df_weather_bobcat = df_weather_bobcat.drop(['site_id', 'precipDepth6HR'], axis=1)

df_weather_bobcat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17525 entries, 2016-01-01 00:00:00 to 2017-12-31 23:00:00
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   airTemperature  17494 non-null  float64
#  1   cloudCoverage   12595 non-null  float64
#  2   dewTemperature  17491 non-null  float64
#  3   precipDepth1HR  17483 non-null  float64
#  4   seaLvlPressure  17274 non-null  float64
#  5   windDirection   16475 non-null  float64
#  6   windSpeed       17379 non-null  float64
# dtypes: float64(7)
# memory usage: 1.1+ MB

# %%
#This dataframe has missing information that is not desplayed as nulls but as rows that dont exist at all and must be considered for the time series 
# so we will create an empty dataframe with all the timestamps and then merge it with the weather dataframe to fill the missing values

start_date = '2016-01-01 00:00:00'
end_date = '2017-12-31 23:00:00'
interval = '1H'

index = pd.date_range(start=start_date, end=end_date, freq=interval) # Created a Index Dtype Timestamp
df_time = pd.DataFrame(index=index)

df_time.index = pd.to_datetime(df_time.index)
df_weather_bobcat.index = pd.to_datetime(df_weather_bobcat.index)

merged_df = df_time.merge(df_weather_bobcat , left_index=True, right_index=True, how='left')

df_weather_bobcat = merged_df.copy()

null_values = []
for col in df_weather_bobcat.columns:    
    null_values.append(count_null_incol(df_weather_bobcat, col))
# Out:
# Total null values in column airTemperature: 50
# Total null values in column cloudCoverage: 4949
# Total null values in column dewTemperature: 53
# Total null values in column precipDepth1HR: 61
# Total null values in column seaLvlPressure: 270
# Total null values in column windDirection: 1069
# Total null values in column windSpeed: 165

# %% [markdown]
# ## Building data

# %%
# Import all the dataframes about the sensor's buldings 
df_gas = pd.read_csv('gas_cleaned.csv')
df_hotwater = pd.read_csv('hotwater_cleaned.csv')
df_irrigation = pd.read_csv('irrigation_cleaned.csv')
df_solar = pd.read_csv('solar_cleaned.csv')
df_steam = pd.read_csv('steam_cleaned.csv')
df_water = pd.read_csv('water_cleaned.csv')
df_electricity = pd.read_csv('electricity.csv')

# %%
# In this section we will take the column timestamp from all the dataframes and we will convert it to datetime format and set is as the index 
# of the dataframe

df_gas['timestamp'] = pd.to_datetime(df_gas['timestamp'])
df_gas.set_index('timestamp', inplace=True, drop=True)

df_hotwater['timestamp'] = pd.to_datetime(df_hotwater['timestamp']) 
df_hotwater.set_index('timestamp', inplace=True, drop=True) 

df_irrigation['timestamp'] = pd.to_datetime(df_irrigation['timestamp'])
df_irrigation.set_index('timestamp', inplace=True, drop=True)   

df_solar['timestamp'] = pd.to_datetime(df_solar['timestamp'])       
df_solar.set_index('timestamp', inplace=True, drop=True)    

df_steam['timestamp'] = pd.to_datetime(df_steam['timestamp'])
df_steam.set_index('timestamp', inplace=True, drop=True)

df_water['timestamp'] = pd.to_datetime(df_water['timestamp'])   
df_water.set_index('timestamp', inplace=True, drop=True)    

df_electricity['timestamp'] = pd.to_datetime(df_electricity['timestamp'])
df_electricity.set_index('timestamp', inplace=True, drop=True)

# %%
#We create a list that contains all the dataframes
df_name_list = [df_gas, df_hotwater, df_irrigation, df_solar, df_steam, df_water, df_electricity]

# %%
#We will append the datasets df_solar, df_water, df_electricity into a new dataframe called df_timothy
df_timothy = pd.DataFrame()
df_timothy['solar'] = df_solar['Bobcat_other_Timothy']
df_timothy['water'] = df_water['Bobcat_other_Timothy']
df_timothy['electricity'] = df_electricity['Bobcat_other_Timothy']

# %%
df_timothy.head()
# Out:
#                      solar  water  electricity
# timestamp
# 2016-01-01 00:00:00   0.02    0.0      36.0900
# 2016-01-01 01:00:00   0.01    0.0      36.3800
# 2016-01-01 02:00:00   0.02    0.0      34.7501
# 2016-01-01 03:00:00   0.02    0.0      36.4700
# 2016-01-01 04:00:00   0.00    0.0      35.3400

# %% [markdown]
# ## Table append

# %%
new_df = df_weather_bobcat.merge(df_timothy, left_index=True, right_index=True, how='left')
print(new_df.isnull().sum())
# Out:
# airTemperature      50
# cloudCoverage     4949
# dewTemperature      53
# precipDepth1HR      61
# seaLvlPressure     270
# windDirection     1069
# windSpeed          165
# solar              370
# water              452
# electricity         25
# dtype: int64

# %%
column_names = new_df.columns
new_df.head()
# Out:
#                      airTemperature  cloudCoverage  dewTemperature  \
# 2016-01-01 00:00:00           -14.4            0.0           -16.7
# 2016-01-01 01:00:00           -13.3            0.0           -16.7
# 2016-01-01 02:00:00           -15.0            0.0           -17.8
# 2016-01-01 03:00:00           -12.8            0.0           -17.8
# 2016-01-01 04:00:00           -14.4            0.0           -18.3
#
#                      precipDepth1HR  seaLvlPressure  windDirection  windSpeed  \
# 2016-01-01 00:00:00             0.0          1036.9          280.0        3.1
# 2016-01-01 01:00:00             0.0          1036.0          240.0        3.1
# 2016-01-01 02:00:00             0.0          1035.9          240.0        2.6
# 2016-01-01 03:00:00             0.0          1035.0          310.0        2.6
# 2016-01-01 04:00:00             0.0          1035.3          300.0        3.6
#
#                      solar  water  electricity
# 2016-01-01 00:00:00   0.02    0.0      36.0900
# 2016-01-01 01:00:00   0.01    0.0      36.3800
# 2016-01-01 02:00:00   0.02    0.0      34.7501
# 2016-01-01 03:00:00   0.02    0.0      36.4700
# 2016-01-01 04:00:00   0.00    0.0      35.3400

# %%
imputer = KNNImputer(n_neighbors=168)
new_df_imputed_array = imputer.fit_transform(new_df)
new_df_imputed = pd.DataFrame(new_df_imputed_array, columns=new_df.columns, index=new_df.index)
print('Missing values after imputation: ',new_df_imputed.isnull().sum())
# Out:
# Missing values after imputation:  airTemperature    0
# cloudCoverage     0
# dewTemperature    0
# precipDepth1HR    0
# seaLvlPressure    0
# windDirection     0
# windSpeed         0
# solar             0
# water             0
# electricity       0
# dtype: int64

# %%
#We will use a knn interpolation to fill the missing values
imputer = KNNImputer(n_neighbors=168)
new_df = pd.DataFrame(imputer.fit_transform(new_df),columns = column_names, index = new_df.index)
null_count = np.sum(np.isnan(new_df))
print('Missing values after imputation: ', null_count)
df_timothy = new_df.copy()
print(df_timothy.shape)
# Out:
# Missing values after imputation:  airTemperature    0
# cloudCoverage     0
# dewTemperature    0
# precipDepth1HR    0
# seaLvlPressure    0
# windDirection     0
# windSpeed         0
# solar             0
# water             0
# electricity       0
# dtype: int64
# (17544, 10)

# %%
df_timothy.head()
# Out:
#                      airTemperature  cloudCoverage  dewTemperature  \
# 2016-01-01 00:00:00           -14.4            0.0           -16.7
# 2016-01-01 01:00:00           -13.3            0.0           -16.7
# 2016-01-01 02:00:00           -15.0            0.0           -17.8
# 2016-01-01 03:00:00           -12.8            0.0           -17.8
# 2016-01-01 04:00:00           -14.4            0.0           -18.3
#
#                      precipDepth1HR  seaLvlPressure  windDirection  windSpeed  \
# 2016-01-01 00:00:00             0.0          1036.9          280.0        3.1
# 2016-01-01 01:00:00             0.0          1036.0          240.0        3.1
# 2016-01-01 02:00:00             0.0          1035.9          240.0        2.6
# 2016-01-01 03:00:00             0.0          1035.0          310.0        2.6
# 2016-01-01 04:00:00             0.0          1035.3          300.0        3.6
#
#                      solar  water  electricity
# 2016-01-01 00:00:00   0.02    0.0      36.0900
# 2016-01-01 01:00:00   0.01    0.0      36.3800
# 2016-01-01 02:00:00   0.02    0.0      34.7501
# 2016-01-01 03:00:00   0.02    0.0      36.4700
# 2016-01-01 04:00:00   0.00    0.0      35.3400

# %%
#We will use the variables windSpeed and windDirection to create a new variable that will be the wind vector

wv = df_timothy.pop('windSpeed')

# Convert to radians.
wd_rad = df_timothy.pop('windDirection')*np.pi / 180

# Calculate the wind x and y components.
df_timothy['Wx'] = wv*np.cos(wd_rad)
df_timothy['Wy'] = wv*np.sin(wd_rad)

# %%
# Retrieve the column names from the DataFrame
var = df_timothy.columns

# Create subplots to display boxplots
fig, ax = plt.subplots(nrows=5, ncols=2, figsize=(25,12))
fig.subplots_adjust(hspace=1.5)

# Iterate over the columns and create boxplots
for i, var in enumerate(var):
    j = 0 if i%2==0 else 1
    sns.boxplot(x=var, data=df_timothy, ax=ax[i//2,j])

# %%
# Calculate the representativity of outliers in the column
for column in df_timothy.columns:
    representativity = calculate_outlier_representativity(df_timothy[column])
    
    # Print the representativity of outliers in the column
    print(f"The representativity of outliers in column {column} is approximately {round(representativity, 2)}%")
# Out:
# The representativity of outliers in column airTemperature is approximately 0.0%
# The representativity of outliers in column cloudCoverage is approximately 9.62%
# The representativity of outliers in column dewTemperature is approximately 1.05%
# The representativity of outliers in column precipDepth1HR is approximately 10.48%
# The representativity of outliers in column seaLvlPressure is approximately 2.34%
# The representativity of outliers in column solar is approximately 7.26%
# The representativity of outliers in column water is approximately 15.11%
# The representativity of outliers in column electricity is approximately 0.13%
# The representativity of outliers in column Wx is approximately 2.08%
# The representativity of outliers in column Wy is approximately 3.53%

# %%
# Make a line plot analysis of the others Target Variable 

plt.figure(figsize=(25, 6))
plt.plot(df_timothy.index, df_timothy['electricity'])
plt.xlabel('Timestamp')
plt.ylabel('Electricity')
plt.title('Energy consumption over Time')

# Roted the x-axis for better clarity 
plt.xticks(rotation=45)

# Show the plot 
plt.show()

# %%
col_i = ['solar', 'water', 'airTemperature',
       'cloudCoverage', 'dewTemperature', 'precipDepth1HR', 'seaLvlPressure',
       'windDirection', 'windSpeed']

def plotsb(data, var):
    fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(20, 8))
    fig.subplots_adjust(hspace=1.5)
    
# Gráfico de dispersión
    ax1.scatter(data[var], data['electricity'])
    ax1.set_xlabel(var)
    ax1.set_ylabel('Energy Consumption')
    ax1.set_title('Scatter Plot: Energy Consumption vs {}'.format(var))

# Diagrama de caja
    ax2.boxplot(data[var].dropna())
    ax2.set_ylabel('Electricity')
    ax2.set_title('Box Plot: {}'.format(var))

# Mostrar los subplots
    plt.show()

# %%
def times(data, var): 
    # Crear la gráfica

    plt.figure(figsize=(25, 6))
    plt.plot(data.index, data[var])
    plt.xlabel('Timestamp')
    plt.ylabel(var)
    plt.title('{} over Time'.format(var))

# Rotar las etiquetas del eje x para mayor claridad (opcional)
    plt.xticks(rotation=45)

# Mostrar la gráfica
    plt.show()

# %%
plotsb(df_timothy, 'airTemperature')
times(df_timothy, 'airTemperature')

# %%
plotsb(df_timothy, 'cloudCoverage')
times(df_timothy, 'cloudCoverage')

# %%
plotsb(df_timothy, 'dewTemperature')
times(df_timothy, 'dewTemperature')

# %%
### Analsis de Varianza 

def covdata(datos, var): 
    # Cargar los datos de la serie temporal en un DataFrame de Pandas
    data = datos[var]
    
    # Calcular la media de la serie
    means = float(data.mean())

# Calcular la desviación estándar de la serie
    std = float(data.std())

# Calcular la varianza de la serie
    variance = std ** 2
    print(variance)

# Crear una figura y un eje para trazar la serie temporal
    fig, ax = plt.subplots(figsize= (15,4))

# Trazar la serie temporal y la media
    ax.plot(datos.index, data, label='Serie temporal')
    ax.axhline(means, color='r', label='Media')

# Trazar dos veces la desviación estándar por encima y por debajo de la media
    ax.axhline(means + 2 * std, linestyle='--', color='g', label='2 * Desviación estándar')
    ax.axhline(means - 2 * std, linestyle='--', color='g')

# Configurar las etiquetas del eje x
    ax.tick_params(axis='x', rotation=45)

# Agregar leyenda y título
    ax.legend()
    ax.set_title('Serie temporal {} con media y dos veces la desviación estándar'.format(var))

    plt.show()

# %%
covdata(df_timothy, 'electricity')
# covdata(df2, 'gas')
#covdata(df2, 'hotwater')
# Out:
# 83.14197698149529

# %%
covdata(df_timothy, 'airTemperature')
# Out:
# 127.43399444876079

# %%
covdata(df_timothy, 'cloudCoverage')
# Out:
# 1.1197584168275605

# %%
covdata(df_timothy, 'dewTemperature')
# Out:
# 32.60519752146603

# %%
covdata(df_timothy, 'precipDepth1HR')
# Out:
# 10.126718420712146

# %%
covdata(df_timothy, 'seaLvlPressure')
# Out:
# 71.45926407511122

# %%
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

def desser(var, df_2, start_date, end_date):
    # Convertir las fechas a pd.Timestamp si aún no están en ese formato
    start_date = pd.Timestamp(start_date)
    end_date = pd.Timestamp(end_date)

    # Filtrar el DataFrame para el rango de fechas deseado
    df_filtered = df_2.loc[start_date:end_date]

    # Realizar la descomposición estacional de manera aditiva en el DataFrame filtrado
    SerieDescompuesta = seasonal_decompose(df_filtered[var], model='additive')

    # Configurar el tamaño de la figura
    plt.figure(figsize=(20, 12))  # Ancho: 20 pulgadas, Alto: 12 pulgadas

    # Graficar la descomposición estacional del DataFrame filtrado
    ax = SerieDescompuesta.plot(observed=True, seasonal=True, trend=True, resid=True, weights=False)

    # Establecer las marcas de las fechas y rotarlas 45 grados
    #ax.xaxis.set_tick_params(rotation=45)

    # Mostrar el gráfico
    plt.show()

# %%
df_timothy.isnull().sum()
# Out:
# airTemperature    0
# cloudCoverage     0
# dewTemperature    0
# precipDepth1HR    0
# seaLvlPressure    0
# solar             0
# water             0
# electricity       0
# Wx                0
# Wy                0
# dtype: int64

# %%
df_timothy.columns
# Out:
# Index(['airTemperature', 'cloudCoverage', 'dewTemperature', 'precipDepth1HR',
#        'seaLvlPressure', 'solar', 'water', 'electricity', 'Wx', 'Wy'],
#       dtype='object')

# %%
#We will rearange the order of the columns and will place electricity in the last column
df_timothy = df_timothy[['solar', 'water', 'airTemperature', 'cloudCoverage', 'dewTemperature', 'precipDepth1HR', 'seaLvlPressure', 'Wx', 'Wy', 'electricity']]

# %%
var = df_timothy.columns
desser('electricity', df_timothy, '2016-01-01', '2017-12-31')

# %%
for i in df_timothy.columns:
    desser(i,df_timothy, '2017-10-01', '2017-12-31')

# %% [markdown]
# # LSTM NN data preparation

# %%
#Dataset split
from sklearn.model_selection import train_test_split

train_data, test_data = train_test_split(df_timothy, shuffle = False)

# %%
scaler, df_timothy_scaled = f_scaler(df_timothy)

# %%
train_data.tail()
# Out:
#                      solar  water  airTemperature  cloudCoverage  \
# 2017-07-02 01:00:00   0.02    0.0            21.7            0.0
# 2017-07-02 02:00:00   0.01    0.0            21.1            0.0
# 2017-07-02 03:00:00   0.01    0.0            20.0            0.0
# 2017-07-02 04:00:00   0.01    0.0            21.7            0.0
# 2017-07-02 05:00:00   0.00    0.0            18.9            0.0
#
#                      dewTemperature  precipDepth1HR  seaLvlPressure        Wx  \
# 2017-07-02 01:00:00             4.4             0.0          1008.3 -2.560500
# 2017-07-02 02:00:00             4.4             0.0          1008.2 -4.037712
# 2017-07-02 03:00:00             3.9             0.0          1007.7 -2.443201
# 2017-07-02 04:00:00             5.0             0.0          1008.0  1.992642
# 2017-07-02 05:00:00             4.4             0.0          1008.9 -0.964181
#
#                            Wy  electricity
# 2017-07-02 01:00:00 -0.451485        17.13
# 2017-07-02 02:00:00  0.711958        17.69
# 2017-07-02 03:00:00 -0.889252        16.84
# 2017-07-02 04:00:00  2.374738        17.25
# 2017-07-02 05:00:00 -1.149067        17.13

# %%
X = df_timothy_scaled.iloc[:, :-1].values  # Select all rows and all columns except the last one
y = df_timothy_scaled.iloc[:, -1].values

# %%
past_history = 24
future_target = 1
train_split = 13000
STEP = 1

X_train, y_train = multivariate_data(dataset = X
                   , target = y # first column as target variable
                   , start_index = 0 # tipicaly 0 for train and "train_end_index" for test
                   , end_index = train_split # tipicaly "none" for test
                   , history_size = past_history # past observations to be considered
                   , target_size = future_target # future observations associated to history
                   , step = STEP
                   , single_step = True) # whether to predict a single or multiple points

# %%
past_history = 24
future_target = 1
train_split = 13000
STEP = 1


X_test, y_test = multivariate_data(dataset = X
                   , target = y # first column as target variable
                   , start_index = train_split # tipicaly 0 for train and "train_end_index" for test
                   , end_index = None # tipicaly "none" for test
                   , history_size = past_history # past observations to be considered
                   , target_size = future_target # future observations associated to history
                   , step = STEP
                   , single_step = True) # whether to predict a single or multiple points

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (12976, 24, 9)
# (12976,)
# (4519, 24, 9)
# (4519,)

# %% [markdown]
# # NN Models

# %%
model5 = tf.keras.Sequential()

model5.add(tf.keras.layers.LSTM(256, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
model5.add(tf.keras.layers.Activation('tanh'))
model5.add(tf.keras.layers.LSTM(128, return_sequences=True))
model5.add(tf.keras.layers.Activation('tanh'))
model5.add(tf.keras.layers.LSTM(64, return_sequences=True))
model5.add(tf.keras.layers.Activation('tanh'))
model5.add(tf.keras.layers.LSTM(32, return_sequences=False))
model5.add(tf.keras.layers.Activation('tanh'))
model5.add(tf.keras.layers.Dense(1))


model5.summary()

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                                  patience= 10,
                                                  mode = 'min')

model5.compile(loss=tf.losses.MeanSquaredError(), 
              optimizer=tf.optimizers.Adam(learning_rate=0.001), 
              metrics=[tf.metrics.MeanAbsoluteError()])


history5 = model5.fit(X_train, y_train, epochs= 50,
                              validation_data= (X_test, y_test),
                              shuffle= False,
                              callbacks = [early_stopping])

plot_loss(history5)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 24, 256)           272384
#
#  activation_4 (Activation)   (None, 24, 256)           0
#
#  lstm_5 (LSTM)               (None, 24, 128)           197120
#
#  activation_5 (Activation)   (None, 24, 128)           0
#
#  lstm_6 (LSTM)               (None, 24, 64)            49408
#
#  activation_6 (Activation)   (None, 24, 64)            0
#
#  lstm_7 (LSTM)               (None, 32)                12416
#
#  activation_7 (Activation)   (None, 32)                0
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 531,361
# Trainable params: 531,361
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 406/406 [==============================] - 49s 98ms/step - loss: 0.0064 - mean_absolute_error: 0.0545 - val_loss: 0.0086 - val_mean_absolute_error: 0.0675
# Epoch 2/50
# 406/406 [==============================] - 38s 92ms/step - loss: 0.0061 - mean_absolute_error: 0.0530 - val_loss: 0.0077 - val_mean_absolute_error: 0.0646
# Epoch 3/50
# 406/406 [==============================] - 39s 96ms/step - loss: 0.0074 - mean_absolute_error: 0.0593 - val_loss: 0.0086 - val_mean_absolute_error: 0.0679
# Epoch 4/50
# 406/406 [==============================] - 42s 103ms/step - loss: 0.0081 - mean_absolute_error: 0.0624 - val_loss: 0.0065 - val_mean_absolute_error: 0.0587
# Epoch 5/50
# 406/406 [==============================] - 41s 102ms/step - loss: 0.0077 - mean_absolute_error: 0.0618 - val_loss: 0.0064 - val_mean_absolute_error: 0.0578
# Epoch 6/50
# 406/406 [==============================] - 41s 102ms/step - loss: 0.0071 - mean_absolute_error: 0.0591 - val_loss: 0.0067 - val_mean_absolute_error: 0.0623
# Epoch 7/50
# 406/406 [==============================] - 41s 102ms/step - loss: 0.0096 - mean_absolute_error: 0.0750 - val_loss: 0.0065 - val_mean_absolute_error: 0.0612
# Epoch 8/50
# 406/406 [==============================] - 42s 103ms/step - loss: 0.0096 - mean_absolute_error: 0.0756 - val_loss: 0.0065 - val_mean_absolute_error: 0.0609
# Epoch 9/50
# 406/406 [==============================] - 41s 101ms/step - loss: 0.0096 - mean_absolute_error: 0.0757 - val_loss: 0.0065 - val_mean_absolute_error: 0.0608
# Epoch 10/50
# 406/406 [==============================] - 54s 134ms/step - loss: 0.0095 - mean_absolute_error: 0.0758 - val_loss: 0.0064 - val_mean_absolute_error: 0.0606
# Epoch 11/50
# 406/406 [==============================] - 40s 99ms/step - loss: 0.0095 - mean_absolute_error: 0.0759 - val_loss: 0.0064 - val_mean_absolute_error: 0.0605
# Epoch 12/50
# 406/406 [==============================] - 41s 101ms/step - loss: 0.0095 - mean_absolute_error: 0.0759 - val_loss: 0.0064 - val_mean_absolute_error: 0.0603
# Epoch 13/50
# 406/406 [==============================] - 41s 101ms/step - loss: 0.0095 - mean_absolute_error: 0.0760 - val_loss: 0.0064 - val_mean_absolute_error: 0.0602
# Epoch 14/50
# 406/406 [==============================] - 41s 101ms/step - loss: 0.0095 - mean_absolute_error: 0.0759 - val_loss: 0.0064 - val_mean_absolute_error: 0.0601
# Epoch 15/50
# 406/406 [==============================] - 41s 102ms/step - loss: 0.0095 - mean_absolute_error: 0.0759 - val_loss: 0.0063 - val_mean_absolute_error: 0.0600
# Epoch 16/50
# 406/406 [==============================] - 40s 98ms/step - loss: 0.0095 - mean_absolute_error: 0.0725 - val_loss: 0.0059 - val_mean_absolute_error: 0.0555
# Epoch 17/50
# 406/406 [==============================] - 40s 98ms/step - loss: 0.0063 - mean_absolute_error: 0.0541 - val_loss: 0.0067 - val_mean_absolute_error: 0.0621
# Epoch 18/50
# 406/406 [==============================] - 39s 96ms/step - loss: 0.0093 - mean_absolute_error: 0.0731 - val_loss: 0.0064 - val_mean_absolute_error: 0.0601
# Epoch 19/50
# 406/406 [==============================] - 39s 96ms/step - loss: 0.0094 - mean_absolute_error: 0.0760 - val_loss: 0.0063 - val_mean_absolute_error: 0.0595
# Epoch 20/50
# 406/406 [==============================] - 39s 96ms/step - loss: 0.0094 - mean_absolute_error: 0.0762 - val_loss: 0.0062 - val_mean_absolute_error: 0.0594
# Epoch 21/50
# 406/406 [==============================] - 43s 105ms/step - loss: 0.0094 - mean_absolute_error: 0.0762 - val_loss: 0.0062 - val_mean_absolute_error: 0.0593
# Epoch 22/50
# 406/406 [==============================] - 41s 100ms/step - loss: 0.0094 - mean_absolute_error: 0.0763 - val_loss: 0.0062 - val_mean_absolute_error: 0.0593
# Epoch 23/50
# 406/406 [==============================] - 41s 102ms/step - loss: 0.0094 - mean_absolute_error: 0.0763 - val_loss: 0.0062 - val_mean_absolute_error: 0.0593
# Epoch 24/50
# 406/406 [==============================] - 41s 100ms/step - loss: 0.0094 - mean_absolute_error: 0.0763 - val_loss: 0.0062 - val_mean_absolute_error: 0.0593
# Epoch 25/50
# 406/406 [==============================] - 41s 101ms/step - loss: 0.0094 - mean_absolute_error: 0.0763 - val_loss: 0.0062 - val_mean_absolute_error: 0.0592
# Epoch 26/50
# 406/406 [==============================] - 40s 98ms/step - loss: 0.0097 - mean_absolute_error: 0.0741 - val_loss: 0.0081 - val_mean_absolute_error: 0.0708

# %%
import tensorflow as tf

model = tf.keras.Sequential()
model.add(tf.keras.layers.LSTM(75, input_shape= (X_train.shape[1], X_train.shape[2]), return_sequences=True))
model.add(tf.keras.layers.LSTM(50, return_sequences=False))
model.add(tf.keras.layers.Dense(1))
model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_20 (LSTM)              (None, 24, 75)            25500
#
#  lstm_21 (LSTM)              (None, 50)                25200
#
#  dense_12 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 50751 (198.25 KB)
# Trainable params: 50751 (198.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                                  patience= 10,
                                                  mode = 'min')

model.compile(loss=tf.losses.MeanSquaredError(), 
              optimizer=tf.optimizers.Adam(), 
              metrics=[tf.metrics.MeanAbsoluteError()])


history = model.fit(X_train, y_train, epochs= 50,
                              validation_data= (X_test, y_test),
                              shuffle= False,
                              callbacks = [early_stopping])
# Out:
# Epoch 1/50
# 406/406 [==============================] - 8s 14ms/step - loss: 0.0077 - mean_absolute_error: 0.0589 - val_loss: 0.0092 - val_mean_absolute_error: 0.0700
# Epoch 2/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0082 - mean_absolute_error: 0.0626 - val_loss: 0.0063 - val_mean_absolute_error: 0.0581
# Epoch 3/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0073 - mean_absolute_error: 0.0597 - val_loss: 0.0068 - val_mean_absolute_error: 0.0599
# Epoch 4/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0072 - mean_absolute_error: 0.0591 - val_loss: 0.0069 - val_mean_absolute_error: 0.0606
# Epoch 5/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0072 - mean_absolute_error: 0.0597 - val_loss: 0.0061 - val_mean_absolute_error: 0.0564
# Epoch 6/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0071 - mean_absolute_error: 0.0593 - val_loss: 0.0059 - val_mean_absolute_error: 0.0564
# Epoch 7/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0068 - mean_absolute_error: 0.0573 - val_loss: 0.0096 - val_mean_absolute_error: 0.0694
# Epoch 8/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0073 - mean_absolute_error: 0.0600 - val_loss: 0.0101 - val_mean_absolute_error: 0.0719
# Epoch 9/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0069 - mean_absolute_error: 0.0590 - val_loss: 0.0106 - val_mean_absolute_error: 0.0720
# Epoch 10/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0071 - mean_absolute_error: 0.0595 - val_loss: 0.0080 - val_mean_absolute_error: 0.0632
# Epoch 11/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0062 - mean_absolute_error: 0.0547 - val_loss: 0.0083 - val_mean_absolute_error: 0.0617
# Epoch 12/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0063 - mean_absolute_error: 0.0551 - val_loss: 0.0067 - val_mean_absolute_error: 0.0582
# Epoch 13/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0056 - mean_absolute_error: 0.0520 - val_loss: 0.0059 - val_mean_absolute_error: 0.0545
# Epoch 14/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0052 - mean_absolute_error: 0.0493 - val_loss: 0.0062 - val_mean_absolute_error: 0.0559
# Epoch 15/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0050 - mean_absolute_error: 0.0482 - val_loss: 0.0059 - val_mean_absolute_error: 0.0542
# Epoch 16/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0048 - mean_absolute_error: 0.0469 - val_loss: 0.0058 - val_mean_absolute_error: 0.0527
# Epoch 17/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0046 - mean_absolute_error: 0.0457 - val_loss: 0.0055 - val_mean_absolute_error: 0.0520
# Epoch 18/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0044 - mean_absolute_error: 0.0442 - val_loss: 0.0052 - val_mean_absolute_error: 0.0503
# Epoch 19/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0042 - mean_absolute_error: 0.0430 - val_loss: 0.0050 - val_mean_absolute_error: 0.0493
# Epoch 20/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0039 - mean_absolute_error: 0.0411 - val_loss: 0.0045 - val_mean_absolute_error: 0.0467
# Epoch 21/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0037 - mean_absolute_error: 0.0399 - val_loss: 0.0042 - val_mean_absolute_error: 0.0455
# Epoch 22/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0041 - mean_absolute_error: 0.0411 - val_loss: 0.0041 - val_mean_absolute_error: 0.0453
# Epoch 23/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0036 - mean_absolute_error: 0.0393 - val_loss: 0.0042 - val_mean_absolute_error: 0.0447
# Epoch 24/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0039 - mean_absolute_error: 0.0399 - val_loss: 0.0037 - val_mean_absolute_error: 0.0425
# Epoch 25/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0033 - mean_absolute_error: 0.0376 - val_loss: 0.0042 - val_mean_absolute_error: 0.0445
# Epoch 26/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0036 - mean_absolute_error: 0.0389 - val_loss: 0.0034 - val_mean_absolute_error: 0.0402
# Epoch 27/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0035 - mean_absolute_error: 0.0382 - val_loss: 0.0033 - val_mean_absolute_error: 0.0391
# Epoch 28/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0034 - mean_absolute_error: 0.0371 - val_loss: 0.0037 - val_mean_absolute_error: 0.0413
# Epoch 29/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0035 - mean_absolute_error: 0.0380 - val_loss: 0.0032 - val_mean_absolute_error: 0.0384
# Epoch 30/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0032 - mean_absolute_error: 0.0364 - val_loss: 0.0031 - val_mean_absolute_error: 0.0371
# Epoch 31/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0032 - mean_absolute_error: 0.0358 - val_loss: 0.0030 - val_mean_absolute_error: 0.0365
# Epoch 32/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0032 - mean_absolute_error: 0.0355 - val_loss: 0.0029 - val_mean_absolute_error: 0.0355
# Epoch 33/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0031 - mean_absolute_error: 0.0353 - val_loss: 0.0032 - val_mean_absolute_error: 0.0378
# Epoch 34/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0035 - mean_absolute_error: 0.0362 - val_loss: 0.0028 - val_mean_absolute_error: 0.0353
# Epoch 35/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0030 - mean_absolute_error: 0.0349 - val_loss: 0.0031 - val_mean_absolute_error: 0.0369
# Epoch 36/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0033 - mean_absolute_error: 0.0359 - val_loss: 0.0027 - val_mean_absolute_error: 0.0340
# Epoch 37/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0029 - mean_absolute_error: 0.0337 - val_loss: 0.0029 - val_mean_absolute_error: 0.0356
# Epoch 38/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0031 - mean_absolute_error: 0.0350 - val_loss: 0.0025 - val_mean_absolute_error: 0.0328
# Epoch 39/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0027 - mean_absolute_error: 0.0325 - val_loss: 0.0028 - val_mean_absolute_error: 0.0344
# Epoch 40/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0032 - mean_absolute_error: 0.0348 - val_loss: 0.0024 - val_mean_absolute_error: 0.0323
# Epoch 41/50
# 406/406 [==============================] - 6s 15ms/step - loss: 0.0030 - mean_absolute_error: 0.0340 - val_loss: 0.0028 - val_mean_absolute_error: 0.0350
# Epoch 42/50
# 406/406 [==============================] - 5s 13ms/step - loss: 0.0029 - mean_absolute_error: 0.0338 - val_loss: 0.0028 - val_mean_absolute_error: 0.0341
# Epoch 43/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0034 - mean_absolute_error: 0.0355 - val_loss: 0.0023 - val_mean_absolute_error: 0.0314
# Epoch 44/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0027 - mean_absolute_error: 0.0318 - val_loss: 0.0026 - val_mean_absolute_error: 0.0330
# Epoch 45/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0030 - mean_absolute_error: 0.0337 - val_loss: 0.0023 - val_mean_absolute_error: 0.0311
# Epoch 46/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0026 - mean_absolute_error: 0.0314 - val_loss: 0.0025 - val_mean_absolute_error: 0.0322
# Epoch 47/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0030 - mean_absolute_error: 0.0334 - val_loss: 0.0023 - val_mean_absolute_error: 0.0311
# Epoch 48/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0026 - mean_absolute_error: 0.0313 - val_loss: 0.0026 - val_mean_absolute_error: 0.0325
# Epoch 49/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0031 - mean_absolute_error: 0.0340 - val_loss: 0.0022 - val_mean_absolute_error: 0.0305
# Epoch 50/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0026 - mean_absolute_error: 0.0314 - val_loss: 0.0025 - val_mean_absolute_error: 0.0321

# %%
plot_loss(history)

# %%
predictions = model.predict(X_test[:100])  # Adjust the range as needed

# Plot predictions vs real values
plt.plot(range(100), predictions, 'b', label='Predictions')
plt.plot(range(100), y_test[:100], 'r', label='Real Values')
plt.title('Predictions vs Real Values')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 4/4 [==============================] - 0s 4ms/step

# %%
model2 = tf.keras.Sequential()

model2.add(tf.keras.layers.LSTM(64, input_shape= (X_train.shape[1], X_train.shape[2]), return_sequences=True))
model2.add(tf.keras.layers.LSTM(64, activation='tanh', return_sequences=False))
model2.add(tf.keras.layers.Dense(1))

model2.summary()

model2.compile(loss=tf.losses.MeanSquaredError(), 
              optimizer=tf.optimizers.Adam(), 
              metrics=[tf.metrics.MeanAbsoluteError()])


history2 = model2.fit(X_train, y_train, epochs= 50,
                              validation_data= (X_test, y_test),
                              shuffle= False,
                              callbacks = [early_stopping])

plot_loss(history2)
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_22 (LSTM)              (None, 24, 64)            18944
#
#  lstm_23 (LSTM)              (None, 64)                33024
#
#  dense_13 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 52033 (203.25 KB)
# Trainable params: 52033 (203.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 406/406 [==============================] - 8s 13ms/step - loss: 0.0076 - mean_absolute_error: 0.0604 - val_loss: 0.0084 - val_mean_absolute_error: 0.0667
# Epoch 2/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0081 - mean_absolute_error: 0.0623 - val_loss: 0.0064 - val_mean_absolute_error: 0.0580
# Epoch 3/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0074 - mean_absolute_error: 0.0597 - val_loss: 0.0071 - val_mean_absolute_error: 0.0609
# Epoch 4/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0072 - mean_absolute_error: 0.0600 - val_loss: 0.0065 - val_mean_absolute_error: 0.0583
# Epoch 5/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0072 - mean_absolute_error: 0.0596 - val_loss: 0.0063 - val_mean_absolute_error: 0.0578
# Epoch 6/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0068 - mean_absolute_error: 0.0583 - val_loss: 0.0081 - val_mean_absolute_error: 0.0643
# Epoch 7/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0070 - mean_absolute_error: 0.0588 - val_loss: 0.0097 - val_mean_absolute_error: 0.0694
# Epoch 8/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0070 - mean_absolute_error: 0.0587 - val_loss: 0.0103 - val_mean_absolute_error: 0.0713
# Epoch 9/50
# 406/406 [==============================] - 5s 13ms/step - loss: 0.0068 - mean_absolute_error: 0.0576 - val_loss: 0.0097 - val_mean_absolute_error: 0.0672
# Epoch 10/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0069 - mean_absolute_error: 0.0588 - val_loss: 0.0078 - val_mean_absolute_error: 0.0619
# Epoch 11/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0065 - mean_absolute_error: 0.0567 - val_loss: 0.0082 - val_mean_absolute_error: 0.0622
# Epoch 12/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0059 - mean_absolute_error: 0.0527 - val_loss: 0.0074 - val_mean_absolute_error: 0.0583
# Epoch 13/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0061 - mean_absolute_error: 0.0537 - val_loss: 0.0058 - val_mean_absolute_error: 0.0541
# Epoch 14/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0054 - mean_absolute_error: 0.0510 - val_loss: 0.0054 - val_mean_absolute_error: 0.0515
# Epoch 15/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0050 - mean_absolute_error: 0.0485 - val_loss: 0.0053 - val_mean_absolute_error: 0.0510
# Epoch 16/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0048 - mean_absolute_error: 0.0465 - val_loss: 0.0053 - val_mean_absolute_error: 0.0507
# Epoch 17/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0047 - mean_absolute_error: 0.0458 - val_loss: 0.0053 - val_mean_absolute_error: 0.0504
# Epoch 18/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0044 - mean_absolute_error: 0.0442 - val_loss: 0.0046 - val_mean_absolute_error: 0.0470
# Epoch 19/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0039 - mean_absolute_error: 0.0412 - val_loss: 0.0045 - val_mean_absolute_error: 0.0461
# Epoch 20/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0038 - mean_absolute_error: 0.0402 - val_loss: 0.0037 - val_mean_absolute_error: 0.0431
# Epoch 21/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0037 - mean_absolute_error: 0.0393 - val_loss: 0.0039 - val_mean_absolute_error: 0.0433
# Epoch 22/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0042 - mean_absolute_error: 0.0408 - val_loss: 0.0036 - val_mean_absolute_error: 0.0424
# Epoch 23/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0035 - mean_absolute_error: 0.0387 - val_loss: 0.0036 - val_mean_absolute_error: 0.0419
# Epoch 24/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0035 - mean_absolute_error: 0.0382 - val_loss: 0.0034 - val_mean_absolute_error: 0.0401
# Epoch 25/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0034 - mean_absolute_error: 0.0376 - val_loss: 0.0036 - val_mean_absolute_error: 0.0412
# Epoch 26/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0034 - mean_absolute_error: 0.0377 - val_loss: 0.0031 - val_mean_absolute_error: 0.0383
# Epoch 27/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0032 - mean_absolute_error: 0.0365 - val_loss: 0.0032 - val_mean_absolute_error: 0.0388
# Epoch 28/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0033 - mean_absolute_error: 0.0364 - val_loss: 0.0029 - val_mean_absolute_error: 0.0369
# Epoch 29/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0032 - mean_absolute_error: 0.0357 - val_loss: 0.0031 - val_mean_absolute_error: 0.0377
# Epoch 30/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0035 - mean_absolute_error: 0.0359 - val_loss: 0.0031 - val_mean_absolute_error: 0.0378
# Epoch 31/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0033 - mean_absolute_error: 0.0361 - val_loss: 0.0028 - val_mean_absolute_error: 0.0360
# Epoch 32/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0034 - mean_absolute_error: 0.0361 - val_loss: 0.0038 - val_mean_absolute_error: 0.0413
# Epoch 33/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0034 - mean_absolute_error: 0.0374 - val_loss: 0.0028 - val_mean_absolute_error: 0.0353
# Epoch 34/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0030 - mean_absolute_error: 0.0347 - val_loss: 0.0027 - val_mean_absolute_error: 0.0349
# Epoch 35/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0030 - mean_absolute_error: 0.0344 - val_loss: 0.0027 - val_mean_absolute_error: 0.0350
# Epoch 36/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0030 - mean_absolute_error: 0.0346 - val_loss: 0.0027 - val_mean_absolute_error: 0.0345
# Epoch 37/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0030 - mean_absolute_error: 0.0342 - val_loss: 0.0026 - val_mean_absolute_error: 0.0342
# Epoch 38/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0030 - mean_absolute_error: 0.0343 - val_loss: 0.0026 - val_mean_absolute_error: 0.0338
# Epoch 39/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0029 - mean_absolute_error: 0.0340 - val_loss: 0.0026 - val_mean_absolute_error: 0.0341
# Epoch 40/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0033 - mean_absolute_error: 0.0350 - val_loss: 0.0026 - val_mean_absolute_error: 0.0343
# Epoch 41/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0030 - mean_absolute_error: 0.0339 - val_loss: 0.0026 - val_mean_absolute_error: 0.0339
# Epoch 42/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0029 - mean_absolute_error: 0.0338 - val_loss: 0.0025 - val_mean_absolute_error: 0.0331
# Epoch 43/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0030 - mean_absolute_error: 0.0340 - val_loss: 0.0024 - val_mean_absolute_error: 0.0325
# Epoch 44/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0028 - mean_absolute_error: 0.0333 - val_loss: 0.0025 - val_mean_absolute_error: 0.0331
# Epoch 45/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0029 - mean_absolute_error: 0.0336 - val_loss: 0.0025 - val_mean_absolute_error: 0.0330
# Epoch 46/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0029 - mean_absolute_error: 0.0331 - val_loss: 0.0024 - val_mean_absolute_error: 0.0322
# Epoch 47/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0028 - mean_absolute_error: 0.0326 - val_loss: 0.0024 - val_mean_absolute_error: 0.0324
# Epoch 48/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0033 - mean_absolute_error: 0.0357 - val_loss: 0.0026 - val_mean_absolute_error: 0.0344
# Epoch 49/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0030 - mean_absolute_error: 0.0340 - val_loss: 0.0027 - val_mean_absolute_error: 0.0336
# Epoch 50/50
# 406/406 [==============================] - 5s 12ms/step - loss: 0.0030 - mean_absolute_error: 0.0337 - val_loss: 0.0024 - val_mean_absolute_error: 0.0320

# %%
from keras.layers import LSTM, Dense, Bidirectional

model3 = tf.keras.Sequential()
model3.add(tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, activation='tanh'), input_shape=(X_train.shape[1], X_train.shape[2])))
model3.add(tf.keras.layers.Dense(1, activation='linear'))

model3.summary()

model3.compile(loss=tf.losses.MeanSquaredError(), 
              optimizer=tf.optimizers.Adam(), 
              metrics=[tf.metrics.MeanAbsoluteError()])


history3 = model3.fit(X_train, y_train, epochs= 50,
                              validation_data= (X_test, y_test),
                              shuffle= False)

plot_loss(history3) # Del tiempo de periodo que se esta entrenado y el tiempo del tiempo valido
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirecti  (None, 128)               37888
#  onal)
#
#  dense_14 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 38017 (148.50 KB)
# Trainable params: 38017 (148.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 406/406 [==============================] - 5s 8ms/step - loss: 0.0077 - mean_absolute_error: 0.0598 - val_loss: 0.0062 - val_mean_absolute_error: 0.0573
# Epoch 2/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0080 - mean_absolute_error: 0.0568 - val_loss: 0.0046 - val_mean_absolute_error: 0.0491
# Epoch 3/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0077 - mean_absolute_error: 0.0579 - val_loss: 0.0053 - val_mean_absolute_error: 0.0526
# Epoch 4/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0076 - mean_absolute_error: 0.0588 - val_loss: 0.0061 - val_mean_absolute_error: 0.0562
# Epoch 5/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0074 - mean_absolute_error: 0.0592 - val_loss: 0.0066 - val_mean_absolute_error: 0.0584
# Epoch 6/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0072 - mean_absolute_error: 0.0589 - val_loss: 0.0065 - val_mean_absolute_error: 0.0583
# Epoch 7/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0071 - mean_absolute_error: 0.0577 - val_loss: 0.0058 - val_mean_absolute_error: 0.0550
# Epoch 8/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0068 - mean_absolute_error: 0.0571 - val_loss: 0.0062 - val_mean_absolute_error: 0.0567
# Epoch 9/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0067 - mean_absolute_error: 0.0564 - val_loss: 0.0063 - val_mean_absolute_error: 0.0573
# Epoch 10/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0065 - mean_absolute_error: 0.0556 - val_loss: 0.0069 - val_mean_absolute_error: 0.0589
# Epoch 11/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0063 - mean_absolute_error: 0.0549 - val_loss: 0.0074 - val_mean_absolute_error: 0.0608
# Epoch 12/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0057 - mean_absolute_error: 0.0514 - val_loss: 0.0079 - val_mean_absolute_error: 0.0610
# Epoch 13/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0061 - mean_absolute_error: 0.0540 - val_loss: 0.0073 - val_mean_absolute_error: 0.0593
# Epoch 14/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0059 - mean_absolute_error: 0.0529 - val_loss: 0.0068 - val_mean_absolute_error: 0.0566
# Epoch 15/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0056 - mean_absolute_error: 0.0514 - val_loss: 0.0062 - val_mean_absolute_error: 0.0541
# Epoch 16/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0053 - mean_absolute_error: 0.0497 - val_loss: 0.0054 - val_mean_absolute_error: 0.0504
# Epoch 17/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0050 - mean_absolute_error: 0.0479 - val_loss: 0.0050 - val_mean_absolute_error: 0.0481
# Epoch 18/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0048 - mean_absolute_error: 0.0466 - val_loss: 0.0044 - val_mean_absolute_error: 0.0454
# Epoch 19/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0045 - mean_absolute_error: 0.0447 - val_loss: 0.0045 - val_mean_absolute_error: 0.0453
# Epoch 20/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0045 - mean_absolute_error: 0.0445 - val_loss: 0.0041 - val_mean_absolute_error: 0.0433
# Epoch 21/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0043 - mean_absolute_error: 0.0429 - val_loss: 0.0040 - val_mean_absolute_error: 0.0430
# Epoch 22/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0042 - mean_absolute_error: 0.0429 - val_loss: 0.0041 - val_mean_absolute_error: 0.0432
# Epoch 23/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0042 - mean_absolute_error: 0.0424 - val_loss: 0.0039 - val_mean_absolute_error: 0.0419
# Epoch 24/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0041 - mean_absolute_error: 0.0420 - val_loss: 0.0041 - val_mean_absolute_error: 0.0423
# Epoch 25/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0041 - mean_absolute_error: 0.0418 - val_loss: 0.0036 - val_mean_absolute_error: 0.0406
# Epoch 26/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0039 - mean_absolute_error: 0.0404 - val_loss: 0.0040 - val_mean_absolute_error: 0.0417
# Epoch 27/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0041 - mean_absolute_error: 0.0417 - val_loss: 0.0032 - val_mean_absolute_error: 0.0388
# Epoch 28/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0036 - mean_absolute_error: 0.0389 - val_loss: 0.0039 - val_mean_absolute_error: 0.0410
# Epoch 29/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0042 - mean_absolute_error: 0.0418 - val_loss: 0.0030 - val_mean_absolute_error: 0.0377
# Epoch 30/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0035 - mean_absolute_error: 0.0378 - val_loss: 0.0039 - val_mean_absolute_error: 0.0406
# Epoch 31/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0039 - mean_absolute_error: 0.0411 - val_loss: 0.0031 - val_mean_absolute_error: 0.0377
# Epoch 32/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0034 - mean_absolute_error: 0.0373 - val_loss: 0.0037 - val_mean_absolute_error: 0.0397
# Epoch 33/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0038 - mean_absolute_error: 0.0403 - val_loss: 0.0029 - val_mean_absolute_error: 0.0367
# Epoch 34/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0033 - mean_absolute_error: 0.0369 - val_loss: 0.0035 - val_mean_absolute_error: 0.0390
# Epoch 35/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0070 - mean_absolute_error: 0.0517 - val_loss: 0.0051 - val_mean_absolute_error: 0.0506
# Epoch 36/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0060 - mean_absolute_error: 0.0519 - val_loss: 0.0046 - val_mean_absolute_error: 0.0455
# Epoch 37/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0054 - mean_absolute_error: 0.0486 - val_loss: 0.0050 - val_mean_absolute_error: 0.0484
# Epoch 38/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0049 - mean_absolute_error: 0.0467 - val_loss: 0.0049 - val_mean_absolute_error: 0.0478
# Epoch 39/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0044 - mean_absolute_error: 0.0438 - val_loss: 0.0038 - val_mean_absolute_error: 0.0430
# Epoch 40/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0046 - mean_absolute_error: 0.0446 - val_loss: 0.0038 - val_mean_absolute_error: 0.0430
# Epoch 41/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0037 - mean_absolute_error: 0.0395 - val_loss: 0.0040 - val_mean_absolute_error: 0.0432
# Epoch 42/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0041 - mean_absolute_error: 0.0416 - val_loss: 0.0033 - val_mean_absolute_error: 0.0404
# Epoch 43/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0035 - mean_absolute_error: 0.0380 - val_loss: 0.0039 - val_mean_absolute_error: 0.0426
# Epoch 44/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0050 - mean_absolute_error: 0.0464 - val_loss: 0.0043 - val_mean_absolute_error: 0.0460
# Epoch 45/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0037 - mean_absolute_error: 0.0403 - val_loss: 0.0041 - val_mean_absolute_error: 0.0436
# Epoch 46/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0037 - mean_absolute_error: 0.0406 - val_loss: 0.0035 - val_mean_absolute_error: 0.0408
# Epoch 47/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0034 - mean_absolute_error: 0.0384 - val_loss: 0.0035 - val_mean_absolute_error: 0.0408
# Epoch 48/50
# 406/406 [==============================] - 3s 8ms/step - loss: 0.0033 - mean_absolute_error: 0.0381 - val_loss: 0.0033 - val_mean_absolute_error: 0.0394
# Epoch 49/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0033 - mean_absolute_error: 0.0377 - val_loss: 0.0032 - val_mean_absolute_error: 0.0388
# Epoch 50/50
# 406/406 [==============================] - 3s 7ms/step - loss: 0.0032 - mean_absolute_error: 0.0371 - val_loss: 0.0032 - val_mean_absolute_error: 0.0385

# %%
# %pip install keras-attention
# Out:
# Requirement already satisfied: keras-attention in c:\users\carlos vidales\documents\mbds\pfg\codigo\.venv\lib\site-packages (1.0.0)
# Requirement already satisfied: keras in c:\users\carlos vidales\documents\mbds\pfg\codigo\.venv\lib\site-packages (from keras-attention) (2.13.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\carlos vidales\documents\mbds\pfg\codigo\.venv\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\carlos vidales\documents\mbds\pfg\codigo\.venv\lib\site-packages)

# %%
from keras.layers import Attention

inputs = tf.keras.Input(shape=(X_train.shape[1], X_train.shape[2]))
lstm_output_1 = tf.keras.layers.LSTM(128, return_sequences=True)(inputs)
lstm_output_2 = tf.keras.layers.LSTM(64, return_sequences=False)(lstm_output_1)
attention = Attention()([lstm_output_2, lstm_output_2])
output = tf.keras.layers.Dense(1, activation='linear')(attention)
model4 = tf.keras.Model(inputs=inputs, outputs=output)

model4.summary()

model4.compile(loss=tf.losses.MeanSquaredError(), 
              optimizer=tf.optimizers.Adam(), 
              metrics=[tf.metrics.MeanAbsoluteError()])


history4 = model4.fit(X_train, y_train, epochs= 50,
                              validation_data= (X_test, y_test),
                              shuffle= False,
                              callbacks = [early_stopping])

plot_loss(history4)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 24, 9)]              0         []
#
#  lstm_25 (LSTM)              (None, 24, 128)              70656     ['input_2[0][0]']
#
#  lstm_26 (LSTM)              (None, 64)                   49408     ['lstm_25[0][0]']
#
#  attention_1 (Attention)     (None, 64)                   0         ['lstm_26[0][0]',
#                                                                      'lstm_26[0][0]']
#
#  dense_15 (Dense)            (None, 1)                    65        ['attention_1[0][0]']
#
# ==================================================================================================
# Total params: 120129 (469.25 KB)
# Trainable params: 120129 (469.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/50
# 406/406 [==============================] - 10s 18ms/step - loss: 0.0081 - mean_absolute_error: 0.0645 - val_loss: 0.0086 - val_mean_absolute_error: 0.0711
# Epoch 2/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0084 - mean_absolute_error: 0.0665 - val_loss: 0.0083 - val_mean_absolute_error: 0.0705
# Epoch 3/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0086 - mean_absolute_error: 0.0693 - val_loss: 0.0084 - val_mean_absolute_error: 0.0717
# Epoch 4/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0094 - mean_absolute_error: 0.0728 - val_loss: 0.0079 - val_mean_absolute_error: 0.0690
# Epoch 5/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0095 - mean_absolute_error: 0.0736 - val_loss: 0.0073 - val_mean_absolute_error: 0.0656
# Epoch 6/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0094 - mean_absolute_error: 0.0742 - val_loss: 0.0070 - val_mean_absolute_error: 0.0641
# Epoch 7/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0094 - mean_absolute_error: 0.0740 - val_loss: 0.0069 - val_mean_absolute_error: 0.0632
# Epoch 8/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0093 - mean_absolute_error: 0.0736 - val_loss: 0.0068 - val_mean_absolute_error: 0.0630
# Epoch 9/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0092 - mean_absolute_error: 0.0736 - val_loss: 0.0067 - val_mean_absolute_error: 0.0627
# Epoch 10/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0091 - mean_absolute_error: 0.0731 - val_loss: 0.0068 - val_mean_absolute_error: 0.0631
# Epoch 11/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0090 - mean_absolute_error: 0.0727 - val_loss: 0.0068 - val_mean_absolute_error: 0.0636
# Epoch 12/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0088 - mean_absolute_error: 0.0719 - val_loss: 0.0068 - val_mean_absolute_error: 0.0641
# Epoch 13/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0086 - mean_absolute_error: 0.0711 - val_loss: 0.0068 - val_mean_absolute_error: 0.0638
# Epoch 14/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0082 - mean_absolute_error: 0.0695 - val_loss: 0.0069 - val_mean_absolute_error: 0.0645
# Epoch 15/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0076 - mean_absolute_error: 0.0667 - val_loss: 0.0072 - val_mean_absolute_error: 0.0662
# Epoch 16/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0072 - mean_absolute_error: 0.0648 - val_loss: 0.0068 - val_mean_absolute_error: 0.0639
# Epoch 17/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0067 - mean_absolute_error: 0.0621 - val_loss: 0.0074 - val_mean_absolute_error: 0.0659
# Epoch 18/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0065 - mean_absolute_error: 0.0605 - val_loss: 0.0087 - val_mean_absolute_error: 0.0698
# Epoch 19/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0057 - mean_absolute_error: 0.0569 - val_loss: 0.0054 - val_mean_absolute_error: 0.0549
# Epoch 20/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0065 - mean_absolute_error: 0.0572 - val_loss: 0.0047 - val_mean_absolute_error: 0.0505
# Epoch 21/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0057 - mean_absolute_error: 0.0533 - val_loss: 0.0044 - val_mean_absolute_error: 0.0488
# Epoch 22/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0045 - mean_absolute_error: 0.0469 - val_loss: 0.0040 - val_mean_absolute_error: 0.0458
# Epoch 23/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0035 - mean_absolute_error: 0.0418 - val_loss: 0.0039 - val_mean_absolute_error: 0.0448
# Epoch 24/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0031 - mean_absolute_error: 0.0401 - val_loss: 0.0031 - val_mean_absolute_error: 0.0402
# Epoch 25/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0035 - mean_absolute_error: 0.0398 - val_loss: 0.0030 - val_mean_absolute_error: 0.0395
# Epoch 26/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0027 - mean_absolute_error: 0.0372 - val_loss: 0.0028 - val_mean_absolute_error: 0.0378
# Epoch 27/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0024 - mean_absolute_error: 0.0352 - val_loss: 0.0028 - val_mean_absolute_error: 0.0374
# Epoch 28/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0023 - mean_absolute_error: 0.0344 - val_loss: 0.0027 - val_mean_absolute_error: 0.0367
# Epoch 29/50
# 406/406 [==============================] - 7s 18ms/step - loss: 0.0022 - mean_absolute_error: 0.0335 - val_loss: 0.0025 - val_mean_absolute_error: 0.0352
# Epoch 30/50
# 406/406 [==============================] - 8s 19ms/step - loss: 0.0021 - mean_absolute_error: 0.0326 - val_loss: 0.0025 - val_mean_absolute_error: 0.0350
# Epoch 31/50
# 406/406 [==============================] - 7s 18ms/step - loss: 0.0023 - mean_absolute_error: 0.0335 - val_loss: 0.0025 - val_mean_absolute_error: 0.0348
# Epoch 32/50
# 406/406 [==============================] - 7s 18ms/step - loss: 0.0021 - mean_absolute_error: 0.0323 - val_loss: 0.0024 - val_mean_absolute_error: 0.0340
# Epoch 33/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0021 - mean_absolute_error: 0.0316 - val_loss: 0.0026 - val_mean_absolute_error: 0.0353
# Epoch 34/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0023 - mean_absolute_error: 0.0335 - val_loss: 0.0025 - val_mean_absolute_error: 0.0354
# Epoch 35/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0021 - mean_absolute_error: 0.0319 - val_loss: 0.0024 - val_mean_absolute_error: 0.0345
# Epoch 36/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0021 - mean_absolute_error: 0.0320 - val_loss: 0.0023 - val_mean_absolute_error: 0.0332
# Epoch 37/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0019 - mean_absolute_error: 0.0302 - val_loss: 0.0024 - val_mean_absolute_error: 0.0343
# Epoch 38/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0020 - mean_absolute_error: 0.0313 - val_loss: 0.0023 - val_mean_absolute_error: 0.0336
# Epoch 39/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0019 - mean_absolute_error: 0.0304 - val_loss: 0.0022 - val_mean_absolute_error: 0.0331
# Epoch 40/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0018 - mean_absolute_error: 0.0297 - val_loss: 0.0022 - val_mean_absolute_error: 0.0331
# Epoch 41/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0019 - mean_absolute_error: 0.0299 - val_loss: 0.0023 - val_mean_absolute_error: 0.0334
# Epoch 42/50
# 406/406 [==============================] - 7s 18ms/step - loss: 0.0018 - mean_absolute_error: 0.0292 - val_loss: 0.0022 - val_mean_absolute_error: 0.0328
# Epoch 43/50
# 406/406 [==============================] - 7s 18ms/step - loss: 0.0018 - mean_absolute_error: 0.0291 - val_loss: 0.0022 - val_mean_absolute_error: 0.0328
# Epoch 44/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0018 - mean_absolute_error: 0.0291 - val_loss: 0.0022 - val_mean_absolute_error: 0.0325
# Epoch 45/50
# 406/406 [==============================] - 7s 18ms/step - loss: 0.0018 - mean_absolute_error: 0.0290 - val_loss: 0.0022 - val_mean_absolute_error: 0.0325
# Epoch 46/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0018 - mean_absolute_error: 0.0288 - val_loss: 0.0023 - val_mean_absolute_error: 0.0327
# Epoch 47/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0017 - mean_absolute_error: 0.0284 - val_loss: 0.0022 - val_mean_absolute_error: 0.0325
# Epoch 48/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0018 - mean_absolute_error: 0.0287 - val_loss: 0.0022 - val_mean_absolute_error: 0.0319
# Epoch 49/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0018 - mean_absolute_error: 0.0285 - val_loss: 0.0024 - val_mean_absolute_error: 0.0335
# Epoch 50/50
# 406/406 [==============================] - 7s 17ms/step - loss: 0.0018 - mean_absolute_error: 0.0291 - val_loss: 0.0022 - val_mean_absolute_error: 0.0320

# %%
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training loss_1')
plt.plot(history.history['val_loss'], label='Validation loss_1')
plt.plot(history2.history['loss'], label='Training loss_2')
plt.plot(history2.history['val_loss'], label='Validation loss_2')
plt.plot(history3.history['loss'], label='Training loss_3')
plt.plot(history3.history['val_loss'], label='Validation loss_3')
plt.plot(history4.history['loss'], label='Training loss_4')
plt.plot(history4.history['val_loss'], label='Validation loss_4')
plt.plot(history5.history['loss'], label='Training loss_5')
plt.plot(history5.history['val_loss'], label='Validation loss_5')
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
predictions1 = model.predict(X_test[:100])  # Adjust the range as needed
predictions2 = model2.predict(X_test[:100])
predictions3 = model3.predict(X_test[:100])
predictions4 = model4.predict(X_test[:100])
predictions5 = model5.predict(X_test[:100])

# Plot predictions vs real values
plt.plot(range(100), predictions, 'b', label='Predictions')
plt.plot(range(100), predictions2, 'g', label='Predictions2')
plt.plot(range(100), predictions3, 'y', label='Predictions3')
plt.plot(range(100), predictions4, 'r', label='Predictions4')
plt.plot(range(100), y_test[:100], 'p', label='Real Values')
plt.title('Predictions vs Real Values')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 2s 4ms/step
# 4/4 [==============================] - 1s 7ms/step
# 4/4 [==============================] - 1s 19ms/step

# %%
# Plot predictions vs real values
plt.figure(figsize=(50, 6))  # Set the width and height of the plot

plt.plot(range(100), predictions1, 'b', label='Predictions1')
plt.plot(range(100), predictions2, 'g', label='Predictions2')
plt.plot(range(100), predictions3, 'y', label='Predictions3')
plt.plot(range(100), predictions4, 'r', label='Predictions4')
plt.plot(range(100), predictions5, '#000000', label='Predictions4')
plt.plot(range(100), y_test[:100], 'p', label='Real Values')
plt.title('Predictions vs Real Values')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error

predictions1 = model.predict(X_test)  # Adjust the range as needed
predictions2 = model2.predict(X_test)
predictions3 = model3.predict(X_test)
predictions4 = model4.predict(X_test)
predictions5 = model4.predict(X_test)


mae1 = mean_absolute_error(y_test, predictions1)
mae2 = mean_absolute_error(y_test, predictions2)
mae3 = mean_absolute_error(y_test, predictions3)
mae4 = mean_absolute_error(y_test, predictions4)
mae5 = mean_absolute_error(y_test, predictions5)
# Out:
#   1/142 [..............................] - ETA: 3s
# 142/142 [==============================] - 1s 5ms/step
# 142/142 [==============================] - 1s 6ms/step
# 142/142 [==============================] - 0s 3ms/step
# 142/142 [==============================] - 1s 8ms/step
# 142/142 [==============================] - 1s 8ms/step

# %%
print(mae1)
print(mae2)
print(mae3)
print(mae4)
print(mae5)
# Out:
# 0.03213825162885223
# 0.03196261755339028
# 0.038517340329131934
# 0.03203777947199165
# 0.03203777947199165
